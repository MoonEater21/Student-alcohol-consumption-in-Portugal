# %% [markdown]
# # Analisis Student Alcohol Consumption in Portugal
#
#
#
# By :
#
# M Attala R (2019104824)

# %% [markdown]
# Datasets: Student Alcohol Consumption [link text](https://www.kaggle.com/uciml/student-alcohol-consumption)

# %% [markdown]
# ## Summarization

# %% [markdown]
# Data diperoleh dalam survei siswa kursus matematika dan bahasa portugis di sekolah menengah. Ini berisi banyak informasi sosial, gender dan studi yang menarik tentang siswa. Anda dapat menggunakannya untuk beberapa EDA atau mencoba memprediksi nilai akhir siswa.
#
#
# > Isi:
#
# Atribut untuk set data student-mat.csv (kursus Matematika) dan student-por.csv (kursus bahasa Portugis):
#
# 1.   school - sekolah siswa (biner: 'GP' - Gabriel Pereira atau 'MS' - Mousinho da Silveira)
# 2. sex - jenis kelamin siswa (biner: 'F' - perempuan atau 'M' - laki-laki)
# 3. age - usia siswa (numerik: dari 15 hingga 22)
# 4. address  - jenis alamat rumah siswa (biner: 'U' - perkotaan atau 'R' - pedesaan)
# 5. famsize - ukuran keluarga (biner: 'LE3' - kurang atau sama dengan 3 atau 'GT3' - lebih besar dari 3)
# 6. Pstatus - status tinggal orang tua (biner: 'T' - tinggal bersama atau 'A' - terpisah)
# 7. Medu - pendidikan ibu (angka: 0 - tidak ada, 1 - pendidikan dasar (kelas 4), kelas 2 – 5 hingga 9, 3 – pendidikan menengah atau 4 – pendidikan tinggi)
# 8. Fedu - pendidikan ayah (angka: 0 - tidak ada, 1 - pendidikan dasar (kelas 4 SD), 2 – 5 hingga 9 kelas, 3 – pendidikan menengah atau 4 – pendidikan tinggi)
# 9. Mjob - pekerjaan ibu (nominal: 'guru', terkait 'kesehatan', 'pelayanan' sipil (misalnya administrasi atau polisi), 'di rumah' atau 'lainnya')
# 10. Fjob - pekerjaan ayah (nominal: 'guru', terkait 'kesehatan', 'pelayanan' sipil (misalnya administrasi atau polisi), 'di rumah' atau 'lainnya')
# 11. reason - alasan memilih sekolah ini (nominal: dekat dengan 'rumah', 'reputasi' sekolah, preferensi 'kursus' atau 'lainnya')
# 12. guardian - wali siswa (nominal: 'ibu', 'ayah' atau 'lainnya')
# 13. traveltime - waktu perjalanan dari rumah ke sekolah (numerik: 1 - <15 menit, 2 - 15 hingga 30 menit, 3 - 30 menit hingga 1 jam, atau 4 - >1 jam)
# 14. studytime - waktu belajar mingguan (angka: 1 - <2 jam, 2 - 2 hingga 5 jam, 3 - 5 hingga 10 jam, atau 4 - >10 jam)
# 15. failures - jumlah kegagalan kelas sebelumnya (numerik: n jika 1<=n<3, selain itu 4)
# 16. schoolsup - dukungan pendidikan tambahan (biner: ya atau tidak)
# 17. famsup - dukungan pendidikan keluarga (biner: ya atau tidak)
# 18. paid - kelas ekstra berbayar dalam mata pelajaran (Matematika atau Portugis) (biner: ya atau tidak)
# 19. activities - kegiatan ekstra kurikuler (biner: ya atau tidak)
# 20. nursery - menghadiri sekolah pembibitan (biner: ya atau tidak)
# 21. higher - ingin mengambil pendidikan tinggi (biner: ya atau tidak)
# 22. internet - Akses internet di rumah (biner: ya atau tidak)
# 23. romantic - dengan hubungan romantis (biner: ya atau tidak)
# 24. famrel - kualitas hubungan keluarga (angka: dari 1 - sangat buruk hingga 5 - sangat baik)
# 25. freetime - waktu luang sepulang sekolah (angka: dari 1 - sangat rendah hingga 5 - sangat tinggi)
# 26. goout - pergi keluar dengan teman-teman (angka: dari 1 - sangat rendah hingga 5 - sangat tinggi)
# 27. Dalc - konsumsi alkohol hari kerja (angka: dari 1 - sangat rendah hingga 5 - sangat tinggi)
# 28. Walc - konsumsi alkohol akhir pekan (angka: dari 1 - sangat rendah hingga 5 - sangat tinggi)
# 29. health - status kesehatan saat ini (angka: dari 1 - sangat buruk hingga 5 - sangat baik)
# 30. absences - jumlah absen sekolah (numerik: dari 0 hingga 93)
#
# Nilai-nilai ini terkait dengan mata pelajaran, Matematika atau Bahasa Portugis:
#
#
#
# * G1 - kelas periode pertama (numerik: dari 0 hingga 20)
# * G2 - kelas periode kedua (numerik: dari 0 hingga 20)
# * G3 - nilai akhir (numerik: dari 0 hingga 20, target keluaran)

# %% [markdown]
# ## Acquisition

# %% [markdown]
# Library Import

# %%
#Library Import

import pandas as pd #Analisis
import numpy as np #Analisis
import matplotlib.pyplot as plt #Visualisasi
import seaborn as sns #Visualisasi
import warnings
warnings.filterwarnings("ignore")


sns.set(color_codes=True)

from sklearn.impute import SimpleImputer #Machine Learning
from sklearn import preprocessing #Machine Learning
from sklearn.cluster import KMeans #Machine Learning
from sklearn.preprocessing import StandardScaler, LabelEncoder #Machine Learning

# %% [markdown]
# Read Dataset

# %%
df = pd.read_csv("E://Work//IT//Data Science//Notebook//Student Alcohol Consumption//Datasets//student-mat.csv")
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %% [markdown]
# Data Untuk Knn

# %%
df1 = pd.read_csv("E://Work//IT//Data Science//Notebook//Student Alcohol Consumption//Datasets//student-mat-2.csv")
df1
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %% [markdown]
# Info

# %%
# Melihat Info

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# Ada beberapa tahap yang kami lakukan:
# - Data Cleaning
# - Data Selection
# - Data Integration

# %% [markdown]
# ### Data Cleaning
# Pada tahap ini ada 2 point yang akan kami ubah, yakni:
# - Membersihkan data duplikat
# - Membersihkan data NaN atau Null

# %% [markdown]
# 1. Membersihkan data duplikat

# %%
#Membersihkan Data Duplikat

df = df.drop_duplicates()
print("Total Data (Baris, Kolom) :", df.shape)
# Out:
# Total Data (Baris, Kolom) : (395, 33)

# %%
#Melihat Jumlah Data Duplikat yang telah dibersihkan

duplicate_rows = df[df.duplicated()]
print("Data Duplikat (Baris, Kolom) :", duplicate_rows.shape)
# Out:
# Data Duplikat (Baris, Kolom) : (0, 33)

# %% [markdown]
# Terlihat bahwa tidak ada data duplikat sehingga proses selesai

# %% [markdown]
# 2.  Membersihkan data NaN atau Null

# %%
#Melihat total data NaN atau Null

df.isnull().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %% [markdown]
# Terlihat bahwa tidak ada data NaN / Null sehingga proses selesai

# %% [markdown]
# ### Data Selection
# Pada  tahap ini saya menyeleksi dan membuang fitur/kolom yang tidak relevan

# %% [markdown]
# Drop data di df (untuk descriptive analisis)

# %%
#Drop unused column

df = df.drop(columns = {"reason","internet","nursery","higher"}, axis = 1)

# %% [markdown]
# Drop data di df1 (untuk Kmeans)

# %%
#Drop unused column df1

df1 = df1.drop(columns = {"school","age","famsize","Pstatus","Medu","Fedu","Mjob","Fjob","reason","guardian","traveltime","studytime","failures","schoolsup","famsup","paid","activities","nursery","higher","internet","romantic",
                          "famrel","freetime","goout","health","absences","G1","G2",}, axis = 1)

# %% [markdown]
# ### Data Integration
# Pada tahap ini kami akan mengganti nama kolom sehingga lebih sederhana dan mudah dipahami

# %%
#Rename column

df = df.rename(columns= {"goout" : "hangout","paid":"xtrapaid","schoolsup" : "scholarship"})

# %% [markdown]
# ## Descriptive

# %% [markdown]
# ### Descriptive Analisis

# %%
df.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime     hangout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %% [markdown]
# Median

# %%
#Median

df.median()
# Out:
# age           17.0
# Medu           3.0
# Fedu           2.0
# traveltime     1.0
# studytime      2.0
# failures       0.0
# famrel         4.0
# freetime       3.0
# hangout        3.0
# Dalc           1.0
# Walc           2.0
# health         4.0
# absences       4.0
# G1            11.0
# G2            11.0
# G3            11.0
# dtype: float64

# %% [markdown]
# Mode

# %%
#Mode

df.mode()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu   Mjob   Fjob  ...  \
# 0     GP   F   16       U     GT3       T     4     2  other  other  ...
#
#   famrel  freetime  hangout  Dalc Walc health absences  G1 G2  G3
# 0      4         3        3     1    1      5        0  10  9  10
#
# [1 rows x 29 columns]

# %% [markdown]
# Mode dalam salah satu kolom

# %%
#Mode on Sex column

df["sex"].mode()
# Out:
# 0    F
# dtype: object

# %% [markdown]
# IQR

# %%
#Q1 & Q3

Q1 = df.quantile(0.25)
Q3 = df.quantile(0.75)
IQR = Q3 - Q1

print(IQR)
# Out:
# age           2.0
# Medu          2.0
# Fedu          1.0
# traveltime    1.0
# studytime     1.0
# failures      0.0
# famrel        1.0
# freetime      1.0
# hangout       2.0
# Dalc          1.0
# Walc          2.0
# health        2.0
# absences      8.0
# G1            5.0
# G2            4.0
# G3            6.0
# dtype: float64

# %% [markdown]
# ### Distribusi Data

# %% [markdown]
# #### Boxplot

# %% [markdown]
# ##### Umur siswa

# %%
sns.boxplot(x=df["age"])
plt.title("Umur Siswa");

# %%
# Outliers Detection

Q1 = df["age"].quantile(0.25)
Q3 = df["age"].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)

print("Batas Bawah = ", lower_bound)
print("Batas Atas = ", upper_bound)
print("Jadi apapun yang berada diluar", lower_bound, " dan", upper_bound, " merupakan Outlier")
# Out:
# Batas Bawah =  13.0
# Batas Atas =  21.0
# Jadi apapun yang berada diluar 13.0  dan 21.0  merupakan Outlier

# %% [markdown]
# ##### Pendidikan ayah

# %%
sns.boxplot(x=df["Fedu"])
plt.title("Pendidikan Ayah");

# %%
# Outliers Detection

Q1 = df["Fedu"].quantile(0.25)
Q3 = df["Fedu"].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)

print("Batas Bawah = ", lower_bound)
print("Batas Atas = ", upper_bound)
print("Jadi apapun yang berada diluar", lower_bound, " dan", upper_bound, " merupakan Outlier")
# Out:
# Batas Bawah =  0.5
# Batas Atas =  4.5
# Jadi apapun yang berada diluar 0.5  dan 4.5  merupakan Outlier

# %% [markdown]
# ##### Pendidikan ibu

# %%
sns.boxplot(x=df["Medu"])
plt.title("Pendidikan Ibu");

# %%
# Outliers Detection

Q1 = df["Medu"].quantile(0.25)
Q3 = df["Medu"].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)

print("Batas Bawah = ", lower_bound)
print("Batas Atas = ", upper_bound)
print("Jadi apapun yang berada diluar", lower_bound, " dan", upper_bound, " merupakan Outlier")
# Out:
# Batas Bawah =  -1.0
# Batas Atas =  7.0
# Jadi apapun yang berada diluar -1.0  dan 7.0  merupakan Outlier

# %% [markdown]
# ##### Waktu tempuh menuju sekolah

# %%
sns.boxplot(x=df["traveltime"])
plt.title("Waktu tempuh menuju sekolah");

# %%
# Outliers Detection

Q1 = df["traveltime"].quantile(0.25)
Q3 = df["traveltime"].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)

print("Batas Bawah = ", lower_bound)
print("Batas Atas = ", upper_bound)
print("Jadi apapun yang berada diluar", lower_bound, " dan", upper_bound, " merupakan Outlier")
# Out:
# Batas Bawah =  -0.5
# Batas Atas =  3.5
# Jadi apapun yang berada diluar -0.5  dan 3.5  merupakan Outlier

# %% [markdown]
# ##### Waktu belajar siswa

# %%
sns.boxplot(x=df["studytime"])
plt.title("Waktu belajar siswa");

# %%
# Outliers Detection

Q1 = df["studytime"].quantile(0.25)
Q3 = df["studytime"].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)

print("Batas Bawah = ", lower_bound)
print("Batas Atas = ", upper_bound)
print("Jadi apapun yang berada diluar", lower_bound, " dan", upper_bound, " merupakan Outlier")
# Out:
# Batas Bawah =  -0.5
# Batas Atas =  3.5
# Jadi apapun yang berada diluar -0.5  dan 3.5  merupakan Outlier

# %% [markdown]
# ##### Siswa yang mengulang kelas

# %%
sns.boxplot(x=df["failures"])
plt.title("Siswa yang mengulang kelas");

# %%
# Outliers Detection

Q1 = df["failures"].quantile(0.25)
Q3 = df["failures"].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)

print("Batas Bawah = ", lower_bound)
print("Batas Atas = ", upper_bound)
print("Jadi apapun yang berada diluar", lower_bound, " dan", upper_bound, " merupakan Outlier")
# Out:
# Batas Bawah =  0.0
# Batas Atas =  0.0
# Jadi apapun yang berada diluar 0.0  dan 0.0  merupakan Outlier

# %% [markdown]
# ##### Waktu luang sepulang sekolah

# %%
sns.boxplot(x=df["freetime"])
plt.title("Waktu Luang Sepulang Sekolah");

# %%
# Outliers Detection

Q1 = df["freetime"].quantile(0.25)
Q3 = df["freetime"].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)

print("Batas Bawah = ", lower_bound)
print("Batas Atas = ", upper_bound)
print("Jadi apapun yang berada diluar", lower_bound, " dan", upper_bound, " merupakan Outlier")
# Out:
# Batas Bawah =  1.5
# Batas Atas =  5.5
# Jadi apapun yang berada diluar 1.5  dan 5.5  merupakan Outlier

# %% [markdown]
# ##### Waktu keluar bersama teman

# %%
sns.boxplot(x=df["hangout"])
plt.title("Waktu keluar bersama teman");

# %%
# Outliers Detection

Q1 = df["hangout"].quantile(0.25)
Q3 = df["hangout"].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)

print("Batas Bawah = ", lower_bound)
print("Batas Atas = ", upper_bound)
print("Jadi apapun yang berada diluar", lower_bound, " dan", upper_bound, " merupakan Outlier")
# Out:
# Batas Bawah =  -1.0
# Batas Atas =  7.0
# Jadi apapun yang berada diluar -1.0  dan 7.0  merupakan Outlier

# %% [markdown]
# ##### Konsumsi alkohol akhir pekan

# %%
sns.boxplot(x=df["Walc"])
plt.title("Konsumsi Alkohol (Akhir Pekan)");

# %%
# Outliers Detection

Q1 = df["Walc"].quantile(0.25)
Q3 = df["Walc"].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)

print("Batas Bawah = ", lower_bound)
print("Batas Atas = ", upper_bound)
print("Jadi apapun yang berada diluar", lower_bound, " dan", upper_bound, " merupakan Outlier")
# Out:
# Batas Bawah =  -2.0
# Batas Atas =  6.0
# Jadi apapun yang berada diluar -2.0  dan 6.0  merupakan Outlier

# %% [markdown]
# ##### Konsumsi alkohol hari sekolah

# %%
sns.boxplot(x=df["Dalc"])
plt.title("Konsumsi Alkohol (Harian)");

# %%
# Outliers Detection

Q1 = df["Dalc"].quantile(0.25)
Q3 = df["Dalc"].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)

print("Batas Bawah = ", lower_bound)
print("Batas Atas = ", upper_bound)
print("Jadi apapun yang berada diluar", lower_bound, " dan", upper_bound, " merupakan Outlier")
# Out:
# Batas Bawah =  -0.5
# Batas Atas =  3.5
# Jadi apapun yang berada diluar -0.5  dan 3.5  merupakan Outlier

# %% [markdown]
# ##### Absensi siswa

# %%
sns.boxplot(x=df["absences"])
plt.title("Absen Siswa");

# %%
# Outliers Detection

Q1 = df["absences"].quantile(0.25)
Q3 = df["absences"].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)

print("Batas Bawah = ", lower_bound)
print("Batas Atas = ", upper_bound)
print("Jadi apapun yang berada diluar", lower_bound, " dan", upper_bound, " merupakan Outlier")
# Out:
# Batas Bawah =  -12.0
# Batas Atas =  20.0
# Jadi apapun yang berada diluar -12.0  dan 20.0  merupakan Outlier

# %% [markdown]
# ##### Nilai ujian 1

# %%
sns.boxplot(x=df["G1"])
plt.title("Grade 1");

# %%
# Outliers Detection

Q1 = df["G1"].quantile(0.25)
Q3 = df["G1"].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)

print("Batas Bawah = ", lower_bound)
print("Batas Atas = ", upper_bound)
print("Jadi apapun yang berada diluar", lower_bound, " dan", upper_bound, " merupakan Outlier")
# Out:
# Batas Bawah =  0.5
# Batas Atas =  20.5
# Jadi apapun yang berada diluar 0.5  dan 20.5  merupakan Outlier

# %% [markdown]
# ##### Nilai ujian 2

# %%
sns.boxplot(x=df["G2"])
plt.title("Grade 2");

# %%
# Outliers Detection

Q1 = df["G2"].quantile(0.25)
Q3 = df["G2"].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)

print("Batas Bawah = ", lower_bound)
print("Batas Atas = ", upper_bound)
print("Jadi apapun yang berada diluar", lower_bound, " dan", upper_bound, " merupakan Outlier")
# Out:
# Batas Bawah =  3.0
# Batas Atas =  19.0
# Jadi apapun yang berada diluar 3.0  dan 19.0  merupakan Outlier

# %% [markdown]
# ##### Nilai ujian 3

# %%
sns.boxplot(x=df["G3"])
plt.title("Grade 3");

# %%
# Outliers Detection

Q1 = df["G3"].quantile(0.25)
Q3 = df["G3"].quantile(0.75)
IQR = Q3 - Q1

lower_bound = Q1 - (1.5 * IQR)
upper_bound = Q3 + (1.5 * IQR)

print("Batas Bawah = ", lower_bound)
print("Batas Atas = ", upper_bound)
print("Jadi apapun yang berada diluar", lower_bound, " dan", upper_bound, " merupakan Outlier")
# Out:
# Batas Bawah =  -1.0
# Batas Atas =  23.0
# Jadi apapun yang berada diluar -1.0  dan 23.0  merupakan Outlier

# %% [markdown]
# #### Histogram

# %% [markdown]
# Umur Siswa

# %%
pd.set_option('max_columns',None)
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 390     MS   M   20       U     LE3       A     2     2  services  services
# 391     MS   M   17       U     LE3       T     3     1  services  services
# 392     MS   M   21       R     GT3       T     1     1     other     other
# 393     MS   M   18       R     LE3       T     3     2  services     other
# 394     MS   M   19       U     LE3       T     1     1     other   at_home
#
# ...

# %% [markdown]
# Pekerjaan Ibu

# %%
#Histogram Pekerjaan Ibu

df.Mjob.value_counts().nlargest(10).plot(kind='bar', figsize=(10,5))
plt.title("Histogram Pekerjaan Ibu");
plt.xlabel("Pekerjaan Ibu");
plt.ylabel("Total");

# %% [markdown]
# Pekerjaan Ayah

# %%
#Histogram Pekerjaan Ayah

df.Fjob.value_counts().nlargest(10).plot(kind='bar', figsize=(10,5))
plt.title("Histogram Pekerjaan Ayah");
plt.xlabel("Pekerjaan Ayah");
plt.ylabel("Total");

# %% [markdown]
# Pendamping Siswa (Orangtua/Wali)

# %%
#Histogram Pendamping Siswa (Orangtua/Wali)

df.guardian.value_counts().nlargest(10).plot(kind='bar', figsize=(10,5))
plt.title("Histogram Pendamping Siswa (Orangtua/Wali)");
plt.xlabel("Pendamping Siswa");
plt.ylabel("Total");

# %% [markdown]
# ## Clustering

# %% [markdown]
# ### K Means

# %% [markdown]
# Merubah value data

# %%
# Merubah Value Data
enc = LabelEncoder()
df1["sex"]= enc.fit_transform(df1["sex"].values)
df1["address"]= enc.fit_transform(df1["address"].values)
df1
# Out:
#      sex  address  Dalc  Walc  G3
# 0      0        1     1     1   6
# 1      0        1     1     1   6
# 2      0        1     2     3  10
# 3      0        1     1     1  15
# 4      0        1     1     2  10
# ..   ...      ...   ...   ...  ..
# 390    1        1     4     5   9
# 391    1        1     3     4  16
# 392    1        0     3     3   7
# 393    1        0     3     4  10
# 394    1        1     3     3   9
#
# [395 rows x 5 columns]

# %% [markdown]
# Menjadikan data kedalam Z score

# %%
#Membuat data menjadi Z score sehingga memiliki mean 0 dan std. deviation 1

scaler = StandardScaler()
df1 = pd.DataFrame(scaler.fit_transform(df1), columns = df1.columns)
df1
# Out:
#           sex   address      Dalc      Walc        G3
# 0   -0.948176  0.535392 -0.540699 -1.003789 -0.964934
# 1   -0.948176  0.535392 -0.540699 -1.003789 -0.964934
# 2   -0.948176  0.535392  0.583385  0.551100 -0.090739
# 3   -0.948176  0.535392 -0.540699 -1.003789  1.002004
# 4   -0.948176  0.535392 -0.540699 -0.226345 -0.090739
# ..        ...       ...       ...       ...       ...
# 390  1.054656  0.535392  2.831553  2.105989 -0.309288
# 391  1.054656  0.535392  1.707469  1.328545  1.220553
# 392  1.054656 -1.867789  1.707469  0.551100 -0.746385
# 393  1.054656 -1.867789  1.707469  1.328545 -0.090739
# 394  1.054656  0.535392  1.707469  0.551100 -0.309288
#
# [395 rows x 5 columns]

# %% [markdown]
# Mengetahui K dengan metode elbow

# %%
# Metode Elbow

inertia_list = []
for i in range(1,11):
    
   kmeans = KMeans(n_clusters = i)
   kmeans.fit(df1)
   inertia_list.append(kmeans.inertia_)
plt.figure(figsize = (8,8));
plt.plot(range(1,11), inertia_list, color = 'blue', linestyle = 'dashed', marker ='o', markerfacecolor = 'red',
         markersize = 10);
plt.title('Inertia vs K Value');
plt.xticks(range(1,11, 1));
plt.xlabel('K');
plt.ylabel('Inertia');

# %% [markdown]
# Mencari kluster

# %%
#K Means Pairplot

km = KMeans(n_clusters =5).fit(df1) 

labeler = LabelEncoder()

#Membaca kembali original data ke variable lain
df1_1 = pd.read_csv("E://Work//IT//Data Science//Notebook//Student Alcohol Consumption//Datasets//student-mat.csv")
df1_1.drop({"school","age","famsize","Pstatus","Medu","Fedu","Mjob","Fjob","reason","guardian","traveltime","studytime","failures","schoolsup","famsup","paid","activities","nursery","higher","internet","romantic",
              "famrel","freetime","goout","health","absences","G1","G2"}, axis = 1, inplace = True)
df1_1["sex"]= enc.fit_transform(df1_1["sex"].values)
df1_1["sex"] = labeler.fit_transform(df1_1["sex"])

#Membuat satu kolom category untuk menampung hasil kluster kita
df1_1["Category"] = km.labels_
sns.pairplot(data = df1_1, hue = 'Category', palette = 'Paired');

# %% [markdown]
# ## Visualization

# %% [markdown]
# ### Pie Chart

# %% [markdown]
# Presentase Sekolah Asal siswa

# %%
#Pie Chart Presentase Sekolah Asal siswa

dataschools = df["school"].unique()
data = [];

for s in dataschools:
    total = df["school"].str.count(s).sum()
    data.append([s, total])

data = pd.DataFrame(data, columns = ["Sekolah", "Sekolah Siswa"])

value = data["Sekolah Siswa"]
plt.title("Presentase Sekolah Asal Siswa");
labels = data["Sekolah"]
plt.pie(value, labels = labels, autopct = "%1.1f%%", radius=2, startangle=90);
#plt.axes().set_aspect("equal");
plt.show();

# %% [markdown]
# Presentase Jenis Kelamin dari Jumlah Siswa

# %%
#Pie Chart Presentase Jenis Kelamin dari Jumlah Siswa

datagender = df["sex"].unique()
data = [];

for s in datagender:
    total = df["sex"].str.count(s).sum()
    data.append([s, total])

data = pd.DataFrame(data, columns = ["Sex", "Presentase Jumlah Siswa"])

value = data["Presentase Jumlah Siswa"]
plt.title("Presentase Jenis Kelamin dari Jumlah Siswa");
labels = data["Sex"]
plt.pie(value, labels = labels, autopct = "%1.1f%%", radius=2, startangle=90);
#plt.axes().set_aspect("equal");
plt.show();

# %% [markdown]
# Presentase Tempat Tinggal Asal Siswa

# %%
#Pie Chart Presentase Tempat Tinggal Asal Siswa

dataaddress = df["address"].unique()
data = [];

for s in dataaddress:
    total = df["address"].str.count(s).sum()
    data.append([s, total])

data = pd.DataFrame(data, columns = ["Alamat", "Tempat Tinggal Siswa"])

value = data["Tempat Tinggal Siswa"]
plt.title("Presentase Tempat Tinggal Asal Siswa")
labels = data["Alamat"]
plt.pie(value, labels = labels, autopct = "%1.1f%%", radius=2, startangle=90);
#plt.axes().set_aspect("equal");
plt.show();

# %% [markdown]
# Presentase Besaran Keluarga Siswa

# %%
#Pie Chart Presentase Besaran Keluarga Siswa

datafamsize = df["famsize"].unique()
data = [];

for s in datafamsize:
    total = df["famsize"].str.count(s).sum()
    data.append([s, total])

data = pd.DataFrame(data, columns = ["Keluarga", "Besaran Keluarga Siswa"])

value = data["Besaran Keluarga Siswa"]
plt.title("Presentase Besaran Keluarga Siswa")
labels = data["Keluarga"]
plt.pie(value, labels = labels, autopct = "%1.1f%%", radius=2, startangle=90);
#plt.axes().set_aspect("equal");
plt.show();

# %% [markdown]
# Presentase Status Tinggal Siswa

# %%
#Pie Chart Presentase Status Tinggal Siswa

dataPstatus = df["Pstatus"].unique()
data = [];

for s in dataPstatus:
    total = df["Pstatus"].str.count(s).sum()
    data.append([s, total])

data = pd.DataFrame(data, columns = ["Status Tinggal", "Status Tinggal Siswa"])

value = data["Status Tinggal Siswa"]
plt.title("Presentase Status Tinggal Siswa")
labels = data["Status Tinggal"]
plt.pie(value, labels = labels, autopct = "%1.1f%%", radius=2, startangle=90);
#plt.axes().set_aspect("equal");
plt.show();

# %% [markdown]
# Presentase Beasiswa

# %%
#Pie Chart Presentase Beasiswa

datascholarship = df["scholarship"].unique()
data = [];

for s in datascholarship:
    total = df["scholarship"].str.count(s).sum()
    data.append([s, total])

data = pd.DataFrame(data, columns = ["Beasiswa", "Siswa Berprestasi"])

value = data["Siswa Berprestasi"]
plt.title("Presentase Beasiswa")
labels = data["Beasiswa"]
plt.pie(value, labels = labels, autopct = "%1.1f%%", radius=2, startangle=90);
#plt.axes().set_aspect("equal");
plt.show();

# %% [markdown]
# Presentase Dukungan biaya dari Keluarga

# %%
#Pie Chart Presentase Dukungan biaya dari Keluarga

datafamsup = df["famsup"].unique()
data = [];

for s in datafamsup:
    total = df["famsup"].str.count(s).sum()
    data.append([s, total])

data = pd.DataFrame(data, columns = ["Supported", "Dukungan"])

value = data["Dukungan"]
plt.title("Presentase Dukungan biaya dari Keluarga")
labels = data["Supported"]
plt.pie(value, labels = labels, autopct = "%1.1f%%", radius=2, startangle=90);
#plt.axes().set_aspect("equal");
plt.show();

# %% [markdown]
# Presentase Siswa yang Mengambil Kelas Ekstra

# %%
#Pie Chart Presentase Siswa yang Mengambil Kelas Ekstra

dataxtra = df["xtrapaid"].unique()
data = [];

for s in dataxtra:
    total = df["xtrapaid"].str.count(s).sum()
    data.append([s, total])

data = pd.DataFrame(data, columns = ["Extra", "Kelas Ekstra"])

value = data["Kelas Ekstra"]
plt.title("Presentase Siswa yang Mengambil Kelas Ekstra")
labels = data["Extra"]
plt.pie(value, labels = labels, autopct = "%1.1f%%", radius=2, startangle=90);
#plt.axes().set_aspect("equal");
plt.show();

# %% [markdown]
# Presentase Siswa yang Mengambil EKstrakulikuler

# %%
#Pie Chart Presentase Siswa yang Mengambil EKstrakulikuler

dataactivities = df["activities"].unique()
data = [];

for s in dataactivities:
    total = df["activities"].str.count(s).sum()
    data.append([s, total])

data = pd.DataFrame(data, columns = ["Aktifitas", "EKstrakulikuler"])

value = data["EKstrakulikuler"]
plt.title("Presentase Siswa yang Mengambil EKstrakulikuler")
labels = data["Aktifitas"]
plt.pie(value, labels = labels, autopct = "%1.1f%%", radius=2, startangle=90);
#plt.axes().set_aspect("equal");
plt.show();

# %% [markdown]
# Presentase Siswa yang sedang dalam Hubungan Romantis

# %%
#Pie Chart Presentase Siswa yang sedang dalam Hubungan Romantis

dataromantic = df["romantic"].unique()
data = [];

for s in dataromantic:
    total = df["romantic"].str.count(s).sum()
    data.append([s, total])

data = pd.DataFrame(data, columns = ["Romantis", "Hubungan Romantis"])

value = data["Hubungan Romantis"]
plt.title("Presentase Siswa yang sedang dalam Hubungan Romantis")
labels = data["Romantis"]
plt.pie(value, labels = labels, autopct = "%1.1f%%", radius=2, startangle=90);
#plt.axes().set_aspect("equal");
plt.show();

# %% [markdown]
# ### Line Plot

# %% [markdown]
# ##### Pengaruh Kesehatan dengan Absensi Siswa

# %%
dataline1 = df["health"].unique()
data = []

for c in dataline1:
    d = df[df["health"] == c]
    counts = d["absences"].count()
    data.append([c, counts])

data = pd.DataFrame(data, columns = ["Kesehatan", "Absensi"])
plt.figure(figsize=(10,5));
plt.title("Pengaruh kesehatan dengan absensi siswa");
ax = sns.lineplot(x="Kesehatan", y="Absensi", data=data)

# %% [markdown]
# Dapat dilihat bahwa siswa dengan tingkat kesehatan rendah memiliki absensi paling rendah. Hal ini dapat berarti siswa tersebut nmenggunakan alasan sakit untuk tidak masuk ataupun memang sakit tidak masuk.

# %% [markdown]
# ##### Pengaruh Umur dengan Absensi Siswa

# %%
dataline8 = df["age"].unique()
data = []

for c in dataline8:
    d = df[df["age"] == c]
    counts = d["absences"].count()
    data.append([c, counts])

data = pd.DataFrame(data, columns = ["Umur", "Absensi"])
plt.figure(figsize=(10,5));
plt.title("Pengaruh umur dengan absensi siswa");
ax = sns.lineplot(x="Umur", y="Absensi", data=data)

# %% [markdown]
# Legal drinking age di Portugal adalah 18 tahun. Dapat dilihat di chart diatas tingkat absen bagi mereka yang berada dibawah usia 18 tahun sangat tinggi, namun mengalami penurunan drastis ketika beralih dari usia 18 ke 19 dan seterusnya.

# %% [markdown]
# ##### Pengaruh Konsumsi Alkohol di hari sekolah dengan Kesehatan Siswa

# %%
dataline2 = df["Dalc"].unique()
data = []

for c in dataline2:
    d = df[df["Dalc"] == c]
    counts = d["health"].count()
    data.append([c, counts])

data = pd.DataFrame(data, columns = ["Konsumsi alkohol (hari sekolah)", "kesehatan"])
plt.figure(figsize=(10,5));
plt.title("Pengaruh konsumsi alkohol di hari sekolah dengan kesehatan siswa");
ax = sns.lineplot(x="Konsumsi alkohol (hari sekolah)", y="kesehatan", data=data)

# %% [markdown]
# Siswa yang tidak mengkonsumsi alkohol di hari sekolah dan di akhir pekan memiliki tingkat kesehatan yang lebih dibanding mereka yang memiliki nilai konsumsi alkohol diatas 2.0 atau rendah. Dapat disimpulkan bahwa walaupun tingkat konsumsi alkohol tersebut rendah, tetap saja memiliki pengaruh yang signifikan jika dikonsumsi setiap hari.

# %% [markdown]
# ##### Pengaruh Konsumsi Alkohol di akhir pekan dengan Kesehatan SIswa

# %%
datatahun = df["Walc"].unique()
data = []

for c in datatahun:
    d = df[df["Walc"] == c]
    counts = d["health"].count()
    data.append([c, counts])

data = pd.DataFrame(data, columns = ["Konsumsi alkohol (akhir pekan)", "kesehatan"])
plt.figure(figsize=(10,5));
plt.title("Pengaruh konsumsi alkohol siswa di akhir pekan dengan kesehatan siswa");
ax = sns.lineplot(x="Konsumsi alkohol (akhir pekan)", y="kesehatan", data=data)

# %% [markdown]
# ##### Pengaruh Konsumsi Alkohol di hari sekolah dengan Absensi Siswa

# %%
dataline3 = df["Dalc"].unique()
data = []

for c in dataline3:
    d = df[df["Dalc"] == c]
    counts = d["absences"].count()
    data.append([c, counts])

data = pd.DataFrame(data, columns = ["Konsumsi alkohol (hari sekolah)", "Absensi"])
plt.figure(figsize=(10,5))
plt.title("Pengaruh konsumsi alkohol di hari sekolah dengan absensi siswa")
ax = sns.lineplot(x="Konsumsi alkohol (hari sekolah)", y="Absensi", data=data)

# %% [markdown]
# ##### Pengaruh Konsumsi Alkohol di akhir pekan dengan Absensi Siswa

# %%
dataline4 = df["Walc"].unique()
data = []

for c in dataline4:
    d = df[df["Walc"] == c]
    counts = d["absences"].count()
    data.append([c, counts])

data = pd.DataFrame(data, columns = ["Konsumsi alkohol (akhir pekan)", "Absensi"])
plt.figure(figsize=(10,5));
plt.title("Pengaruh konsumsi alkohol di hari sekolah dengan absensi siswa");
ax = sns.lineplot(x="Konsumsi alkohol (akhir pekan)", y="Absensi", data=data)

# %% [markdown]
# ##### Pengaruh Grade 1 dengan Konsumsi Alkohol Siswa di Hari Sekolah

# %%
dataline5 = df["G1"].unique()
data = []

for c in dataline5:
    d = df[df["G1"] == c]
    counts = d["Dalc"].count()
    data.append([c, counts])

data = pd.DataFrame(data, columns = ["Nilai G1", "Konsumsi alkohol (hari sekolah)"])
plt.figure(figsize=(10,5));
plt.title("Pengaruh nilai G1 dengan konsumsi alkohol siswa di hari sekolah");
ax = sns.lineplot(x="Nilai G1", y="Konsumsi alkohol (hari sekolah)", data=data)

# %% [markdown]
# ##### Pengaruh Grade 2 dengan Konsumsi Alkohol Siswa di Hari Sekolah

# %%
dataline6 = df["G2"].unique()
data = []

for c in dataline6:
    d = df[df["G2"] == c]
    counts = d["Dalc"].count()
    data.append([c, counts])

data = pd.DataFrame(data, columns = ["Nilai G2", "Konsumsi alkohol (hari sekolah)"])
plt.figure(figsize=(10,5));
plt.title("Pengaruh nilai G2 dengan konsumsi alkohol siswa di hari sekolah");
ax = sns.lineplot(x="Nilai G2", y="Konsumsi alkohol (hari sekolah)", data=data)

# %% [markdown]
# ##### Pengaruh Grade 3 dengan Konsumsi Alkohol Siswa di Hari Sekolah

# %%
dataline7 = df["G3"].unique()
data = []

for c in dataline7:
    d = df[df["G3"] == c]
    counts = d["Dalc"].count()
    data.append([c, counts])

data = pd.DataFrame(data, columns = ["Nilai G3", "Konsumsi alkohol (hari sekolah)"])
plt.figure(figsize=(10,5));
plt.title("Pengaruh nilai G3 dengan konsumsi alkohol siswa di hari sekolah");
ax = sns.lineplot(x="Nilai G3", y="Konsumsi alkohol (hari sekolah)", data=data)

# %% [markdown]
# ##### Pengaruh Konsumsi Alkoho Siswa di hari sekolah dengan Pendidikan Ibu

# %%
dataline10 = df["Dalc"].unique()
data = []

for c in dataline10:
    d = df[df["Dalc"] == c]
    counts = d["Medu"].count()
    data.append([c, counts])

data = pd.DataFrame(data, columns = ["Konsumsi alkohol (hari sekolah)", "Pendidikan Ibu"])
plt.figure(figsize=(10,5));
plt.title("Pengaruh konsumsi alkohol siswa di hari sekolah dengan pendidikan ibu");
ax = sns.lineplot(x="Konsumsi alkohol (hari sekolah)", y="Pendidikan Ibu", data=data)

# %% [markdown]
# ##### Pengaruh Konsumsi Alkohol Siswa di hari sekolah dengan Pendidikan Ayah

# %%
dataline11 = df["Dalc"].unique()
data = []

for c in dataline11:
    d = df[df["Dalc"] == c]
    counts = d["Fedu"].count()
    data.append([c, counts])

data = pd.DataFrame(data, columns = ["Konsumsi alkohol (hari sekolah)", "Pendidikan Ayah"])
plt.figure(figsize=(10,5));
plt.title("Pengaruh konsumsi alkohol siswa di hari sekolah dengan pendidikan ayah");
ax = sns.lineplot(x="Konsumsi alkohol (hari sekolah)", y="Pendidikan Ayah", data=data)

# %% [markdown]
# #### Bar Chart

# %%
# Define Function

def show_values_on_bars(axs, h_v="v", space=0.4):
    def _show_on_single_plot(ax):
        if h_v == "v":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() / 2
                _y = p.get_y() + p.get_height()
                value = int(p.get_height())
                ax.text(_x, _y, value, ha="center") 
        elif h_v == "h":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() + float(space)
                _y = p.get_y() + p.get_height()
                value = int(p.get_width())
                ax.text(_x, _y, value, ha="left")

    if isinstance(axs, np.ndarray):
        for idx, ax in np.ndenumerate(axs):
            _show_on_single_plot(ax)
    else:
        _show_on_single_plot(axs)

# %% [markdown]
# Q: Berapa umur rata - rata siswa yang mengkonsumsi alkohol di akhir pekan?

# %%
databar1 = df["age"].unique()
data = []

for c in databar1:
    d = df[df["age"] == c]
    counts = d["Walc"].mean()
    data.append([c, counts])
    
data = pd.DataFrame(data, columns = ["Umur", "Konsumsi Alkohol (Akhir Pekan)"])

plt.figure(figsize=(10,5));
plt.title("Rata - rata Konsumsi Alkohol Siswa (Akhir Pekan) Berdasarkan Umur");

ax = sns.barplot(x="Umur", y="Konsumsi Alkohol (Akhir Pekan)", data=data)
show_values_on_bars(ax, "v", 0.10)

# %% [markdown]
# Q: Berapa umur rata - rata siswa yang mengkonsumsi alkohol di hari sekolah?

# %%
databar2 = df["age"].unique()
data = []

for c in databar2:
    d = df[df["age"] == c]
    counts = d["Dalc"].mean()
    data.append([c, counts])
    
data = pd.DataFrame(data, columns = ["Umur", "Konsumsi Alkohol (Harian)"])

plt.figure(figsize=(10,5));
plt.title("Rata - rata Konsumsi Alkohol Siswa (Harian) Berdasarkan Umur");

ax = sns.barplot(x="Umur", y="Konsumsi Alkohol (Harian)", data=data)
show_values_on_bars(ax, "v", 0.10)

# %% [markdown]
# Q: Apakah siswa yang mengkonsumsi alkohol di akhir pekan memiliki hubungan keluarga yang kuat?

# %%
databar3 = df["Walc"].unique()
data = []

for c in databar3:
    d = df[df["Walc"] == c]
    counts = d["famrel"].count()
    data.append([c, counts])
    
data = pd.DataFrame(data, columns = ["Konsumsi Alkohol (Akhir Pekan)", "Kualitas Hubungan Keluarga"])

plt.figure(figsize=(10,5));
plt.title("Pengaruh kualitas hubungan keluarga dengan konsumsi alkohol siswa (Akhir Pekan)");

ax = sns.barplot(x="Konsumsi Alkohol (Akhir Pekan)", y="Kualitas Hubungan Keluarga", data=data)
show_values_on_bars(ax, "v", 0.10)

# %% [markdown]
# Q: Apakah siswa yang mengkonsumsi alkohol (hari sekolah) memiliki hubungan keluarga yang kuat?

# %%
databar4 = df["Dalc"].unique()
data = []

for c in databar4:
    d = df[df["Dalc"] == c]
    counts = d["famrel"].count()
    data.append([c, counts])
    
data = pd.DataFrame(data, columns = ["Konsumsi Alkohol (Harian)", "Kualitas Hubungan Keluarga"])

plt.figure(figsize=(10,5));
plt.title("Pengaruh kualitas hubungan keluarga dengan konsumsi alkohol siswa (Harian)");

ax = sns.barplot(x="Konsumsi Alkohol (Harian)", y="Kualitas Hubungan Keluarga", data=data)
show_values_on_bars(ax, "v", 0.10)

# %% [markdown]
# Konsumsi Alkohol hari Sekolah Berdasarkan Gender

# %%
databar5 = df["Dalc"].unique()
data = []

for c in databar5:
    d = df[df["Dalc"] == c]
    female = d["sex"].str.count("F").sum()
    male = d["sex"].str.count("M").sum()
    data.append([c, female, male])

dt = pd.DataFrame(data, columns = ["sex", "F","M"])
dtbar5 = []
dtfemale = []
dtmale = []

for h in dt["sex"]:
    dtbar5.append(h)

for j in dt["F"]:
    dtfemale.append(j)

for i in dt["M"]:
    dtmale.append(i)

dts = pd.DataFrame({'Female': dtfemale, 'Male': dtmale}, index = dtbar5)
ax = dts.plot.barh(figsize=(15,10), title="Konsumsi alkohol (harian) berdasarkan Gender")
        
show_values_on_bars(ax, "h", 0.10)

# %% [markdown]
# Konsumsi Alkohol Akhir Pekan Berdasarkan Gender

# %%
databar6= df["Walc"].unique()
data = []

for c in databar6:
    d = df[df["Walc"] == c]
    female2 = d["sex"].str.count("F").sum()
    male2 = d["sex"].str.count("M").sum()
    data.append([c, female2, male2])

dt = pd.DataFrame(data, columns = ["sex", "F","M"])
dtbar6 = []
dtfemale2 = []
dtmale2 = []

for h in dt["sex"]:
    dtbar6.append(h)

for j in dt["F"]:
    dtfemale2.append(j)

for i in dt["M"]:
    dtmale2.append(i)

dts = pd.DataFrame({'Female': dtfemale2, 'Male': dtmale2}, index = dtbar6)
ax = dts.plot.barh(figsize=(15,10), title="Konsumsi alkohol (akhir pekan) berdasarkan Gender")
        
show_values_on_bars(ax, "h", 0.10)

# %% [markdown]
# ### Violin Plot

# %% [markdown]
# Frekuensi umur siswa

# %%
#Violin Plot Frekuensi Umur Siswa

plt.figure(figsize=(10,6))
plt.title("Ages Frequency")
sns.axes_style("dark")
sns.violinplot(y=df["age"])
plt.show();

# %% [markdown]
# ### Heat Map

# %% [markdown]
# #### Heatmap Keseluruhan

# %%
plt.figure(figsize=(15,5));
c = df.corr()
sns.heatmap(c,cmap="BrBG",annot=True)
c
# Out:
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.000000 -0.163658 -0.163438    0.070641  -0.004140  0.243665
# Medu       -0.163658  1.000000  0.623455   -0.171639   0.064944 -0.236680
# Fedu       -0.163438  0.623455  1.000000   -0.158194  -0.009175 -0.250408
# traveltime  0.070641 -0.171639 -0.158194    1.000000  -0.100909  0.092239
# studytime  -0.004140  0.064944 -0.009175   -0.100909   1.000000 -0.173563
# failures    0.243665 -0.236680 -0.250408    0.092239  -0.173563  1.000000
# famrel      0.053940 -0.003914 -0.001370   -0.016808   0.039731 -0.044337
# freetime    0.016434  0.030891 -0.012846   -0.017025  -0.143198  0.091987
# hangout     0.126964  0.064094  0.043105    0.028540  -0.063904  0.124561
# Dalc        0.131125  0.019834  0.002386    0.138325  -0.196019  0.136047
# Walc        0.117276 -0.047123 -0.012631    0.134116  -0.253785  0.141962
# health     -0.062187 -0.046878  0.014742    0.007501  -0.075616  0.065827
# ...

# %% [markdown]
# #### Heatmap kolom yang berhubungan/ mendekati 1

# %%
plt.figure(figsize=(15,5));
c = df[["Medu","Fedu","Dalc","Walc","G1","G2","G3"]].corr()
sns.heatmap(c,cmap="BrBG",annot=True)
c
# Out:
#           Medu      Fedu      Dalc      Walc        G1        G2        G3
# Medu  1.000000  0.623455  0.019834 -0.047123  0.205341  0.215527  0.217147
# Fedu  0.623455  1.000000  0.002386 -0.012631  0.190270  0.164893  0.152457
# Dalc  0.019834  0.002386  1.000000  0.647544 -0.094159 -0.064120 -0.054660
# Walc -0.047123 -0.012631  0.647544  1.000000 -0.126179 -0.084927 -0.051939
# G1    0.205341  0.190270 -0.094159 -0.126179  1.000000  0.852118  0.801468
# G2    0.215527  0.164893 -0.064120 -0.084927  0.852118  1.000000  0.904868
# G3    0.217147  0.152457 -0.054660 -0.051939  0.801468  0.904868  1.000000
